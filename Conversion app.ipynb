# %% [markdown]
# #### The Conversion App Create a conversion app using functions with parameter and returning their values . The program should be able to perform all the tasks listed on the next page . Minimise the use of variables wherever possible . The output should appear in proper format . For Example : 32 ° Celsius

# %%
def num():
    x=int(input("Enter the number: "))
    
    return x

def num1():
    y=int(input("Enter the number: "))
    return y

def num2():
    y=float(input("Enter the number: "))
    return y

def strg():
    y=input("Enter the character: ")
    return y

def radiant(r):
    import math
    print("180 / pi Degrees is equal to Radians : ", end ="")
    print (math.radians(180 / math.pi))
    print("180 Degrees is equal to Radians : ", end ="")
    print (math.radians(180))
    print(r," Degrees is equal to Radians : ", end ="")
    print(math.radians(r))
    return math.radians(r)
    
def degrees(s):
    import math
    print("pi / 180 Radians is equal to Degrees : ", end ="")
    print (math.degrees(math.pi / 180))
    print("180 Radians is equal to Degrees : ", end ="")
    print (math.degrees(180))
    print(s," Radians is equal to Degrees : ", end ="")
    print (math.degrees(s))
    return math.degrees(s)

def factorial(t):
    import math
    print('Factorial of number',t,'is', end ="")
    print(math.degrees(t))
    return math.factorial(t)
    
def SquareRoot(u):
    import math
    print('Square Root of number',u,'is', end ="")
    print(math.sqrt(u))
    return math.sqrt(u)
    
def nibble(v):
    v = 2000000*num()
    print(v)
    
def Decimal(l,m):
    from fractions import Fraction
    x=Fraction(l,m)
    y=float(x)
    print(y)

    
def ms(o):
    mps = (num() * 1000)/3600
    print("The speed in m/s is",round(mps,2))

def KH(p):
    kh = (num() * 5)/18
    print("The speed in km/h is",round(kh,2))
    
def F(b):
    b = int(num2())
    print(b)
    
def Oc(z):
    print("The octal value of", z, "is:")
    print(oct(z), "is octal.")
    
    
def DCO(decimal_value):
    octal_num = input("Enter an octal number :")
    decimal_value = int(octal_num,8)
    print(decimal_value)

def HEX(g):
    print("The Hexal value of", g, "is:")
    print(hex(g), "is Hexadecimal.")

def DCH(decimal_value):
    H_num = input("Enter an Hexadecimal number :")
    decimal_value = int(H_num,16)
    print(decimal_value)
    
    
def BI(j):
    print("The binary value of", j, "is:")
    print(bin(j), "is binary.")
    
    
def BCH(decimal_value):
    B_num = input("Enter an Binary number :")
    decimal_value = int(B_num,2)
    print(decimal_value)
    
    
def ASCI(s):
    print("The ASCII value of",s, "is", ord(s))


def CH(f):
    print("The ASCII value of given character is", chr(f))

def Fah(s):
    Fahrenheit=(s*1.8)+32
    print(s,'Converted to fahrenheit is',Fahrenheit)

def Cel(s):
    Celcius=(s - 32) * 5/9
    print(s,'Converted to Celcius is',Celcius)

    




def main():
        print("Welcome to Conversion App ")
        print("1. Radians to Degrees")
        print("2. Degrees to Radians")
        print("3. Number to its Factorial ")
        print("4. Number to its Square Root ")
        print("5. Megabyte to Nibble")
        print("6. Fraction to Decimal")
        print("7. Kilometre / Hour to Meter / Second")
        print("8. Meter / Second to Kilometre / Hour ")
        print("9. Integer to Float ")
        print("10. Float to Integer")
        print("11. Decimal to Octal")
        print("12. Octal to Decimal")
        print("13. Decimal to Hexadecimal")
        print("14. Hexadecimal to Decimal")
        print("15. Decimal to Binary Conversion")
        print("16. Binary to Decimal")
        print("17. Character to ASCII")
        print("18. ASCII to Character")
        print("19. Celsius to Fahrenheit ")
        print("20. Fahrenheit to Celsius")
        print("21. Exit")

        choice=int(input("Enter the choice: "))
        if choice==1:
            print("Radians to Degrees")
            c=num()
            radiant(c)
        elif choice==2:
            print("Degrees to Radians")
            c=num()
            degrees(c)
        elif choice==3:
            print("Number to its Factorial")
            c=num()
            factorial(c)
        elif choice==4:
            print("Number to its Square Root")
            c=num()
            SquareRoot(c)
        elif choice==5:
            print("Megabyte to Nibble")
            c=()
            nibble(c)
        elif choice==6:
            print("Fraction to Decimal")
            c,d=num(),num1()
            Decimal(c,d)
        elif choice==7:
            print("Kilometre / Hour to Meter / Second")
            c=()
            ms(c)
        elif choice==8:
            print("Meter / Second to Kilometre / Hour")
            c=()
            KH(c)
        elif choice==9:
            print("Integer to Float")
            c=()
            F(c)
        elif choice==10:
            print("Float to Integer")
        elif choice==11:
            print("Decimal to Octal")
            c=num()
            Oc(c)
        elif choice==12:
            print("Octal to Decimal")
            c=()
            DCO(c)
        elif choice==13:
            print("Decimal to Hexadecimal")
            c=num()
            HEX(c)
        elif choice==14:
            print("Hexadecimal to Decimal")
            c=()
            DCH(c)
        elif choice==15:
            print("Decimal to Binary Conversion")
            c=num()
            BI(c)
        elif choice==16:
            print("Binary to Decimal")
            c=()
            BCH(c)
        elif choice==17:
            print("Character to ASCII")
            c=strg()
            ASCI(c)
        elif choice==18:
            print("ASCII to Character")
            c=num()
            CH(c)
        elif choice==19:
            print("Celsius to Fahrenheit")
            c=num2()
            Fah(c)
        elif choice==20:
            print("Fahrenheit to Celsius")
            c=num2()
            Cel(c)
        
        elif choice==21:
            print("Good day")
main()
# Out:
# Welcome to Conversion App
# 1. Radians to Degrees
# 2. Degrees to Radians
# 3. Number to its Factorial
# 4. Number to its Square Root
# 5. Megabyte to Nibble
# 6. Fraction to Decimal
# 7. Kilometre / Hour to Meter / Second
# 8. Meter / Second to Kilometre / Hour
# 9. Integer to Float
# 10. Float to Integer
# 11. Decimal to Octal
# 12. Octal to Decimal
# 13. Decimal to Hexadecimal
# 14. Hexadecimal to Decimal
# 15. Decimal to Binary Conversion
# 16. Binary to Decimal
# 17. Character to ASCII
# 18. ASCII to Character
# 19. Celsius to Fahrenheit
# 20. Fahrenheit to Celsius
# 21. Exit
# Enter the choice: 6
# Fraction to Decimal
# Enter the number: 12
# Enter the number: 10
# 1.2
